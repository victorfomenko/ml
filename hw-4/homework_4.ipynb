# %% [markdown]
# ## Basic ML Homework
# ### Модуль 4: Теоретический минимум для ML: линейная алгебра, начала мат.анализа

# %% [markdown]
# ## 1. Линейная алгебра

# %% [markdown]
# 1.1 Даны матрицы $A = \begin{pmatrix}
# 2 & −4 \\
# 3 & 5 \\
# −1 & 0
# \end{pmatrix},
# $
# $B = \begin{pmatrix}1 & 2 & 7 \\ −3 & −4 & 0 \\ 5 & 2 & 1 \end{pmatrix}$, $C = \begin{pmatrix}
# 6 & −3 & 9 \\
# 4 & −5 & 2 \\
# 8 & 1 & 5
# \end{pmatrix}.$
#
# Посчитайте матрицу $D = A^{\top}C - 2A^{\top}B^{\top}$. Приведите полную последовательность вычислений.
#
#
# Ответ:
# $A^{\top} = \begin{pmatrix}
# 2 & 3 & -1 \\
# −4 & 5 & 0
# \end{pmatrix}
# \\
# B^{\top} =
# \begin{pmatrix}
# 1 & -3 & 5 \\
# 2 & −4 & 2 \\
# 7 & 0 & 1
# \end{pmatrix}
# $
#
# $A^{\top}C = \begin{pmatrix}
# 2 & 3 & -1 \\
# −4 & 5 & 0
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# 6 & −3 & 9 \\
# 4 & −5 & 2 \\
# 8 & 1 & 5
# \end{pmatrix} =
# \begin{pmatrix}
# 16 & −4 \\
# -22 & −13 \\
# 19 & -26
# \end{pmatrix}
# $
#
# $
# A^{\top}C11 = 2\cdot6 + 3\cdot4 - 1\cdot8 = 16 \\
# A^{\top}C12 = -2\cdot3 - 3\cdot5 - 1\cdot1 = -22 \\
# A^{\top}C13 = 2\cdot9 + 3\cdot2 - 1\cdot5 = 19 \\\\
# \\
# A^{\top}C21 = -4\cdot6 + 5\cdot4 + 0\cdot8 = -4 \\
# A^{\top}C22 = -4\cdot(-3) - 5\cdot5 + 0\cdot1 = -13 \\
# A^{\top}C23 = -4\cdot9 + 5\cdot2 + 0\cdot5 = -26 \\
# $
#
# $A^{\top}C = \begin{pmatrix}
# 16 & -4 \\
# −22 & -13 \\
# 19 & -26
# \end{pmatrix}
# $
#
# $A^{\top}B^{\top} =
# \begin{pmatrix}
# 2 & 3 & -1 \\
# −4 & 5 & 0
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# 1 & -3 & 5 \\
# 2 & −4 & 2 \\
# 7 & 0 & 1
# \end{pmatrix} =
# \begin{pmatrix}
# 1 & 6 \\
# -18 & −8 \\
# 15 & -10
# \end{pmatrix}
# $
#
# $2A^{\top}B^{\top} =
# \begin{pmatrix}
# 2 & 12 \\
# -36 & −16 \\
# 30 & -20
# \end{pmatrix}
# $
#
# $D =
# \begin{pmatrix} 16 & -4 \\ −22 & -13 \\ 19 & -26 \end{pmatrix} -
# \begin{pmatrix} 2 & 12 \\ -36 & −16 \\ 30 & -20 \end{pmatrix} =
# \begin{pmatrix} 14 & -16 \\ 14 & 3 \\ -11 & -6 \end{pmatrix}
# $

# %% [markdown]
# 1.2 Дано:
#
# $ 3 \cdot \begin{pmatrix} x & 2 & 3 \\ −1 & y & 4 \end{pmatrix} +
# 2 \cdot \begin{pmatrix} 1 & 2 & −5 \\ 2 & −6 & z \end{pmatrix} =
# \begin{pmatrix}
# 8 & v & −1 \\
# 1 & 6 & 4 \end{pmatrix}. $
#
# Найдите значения $x$, $y$, $z$, и $v$.
#
# Ответ:
# $
# \\
# A =
# \begin{pmatrix}
# 3x & 6 & 9 \\
# −3 & 3y & 12
# \end{pmatrix}
# +
# \begin{pmatrix}
# 2 & 4 & -10 \\
# 4 & -12 & 2z
# \end{pmatrix} =
# \begin{pmatrix}
# 8 & v & −1 \\
# 1 & 6 & 4 \end{pmatrix}
# $
#
# $
# 3x + 2 = 8\space or \space 3x = 6\space or\space x = 2  \\
# 3y - 12 = 6\space or \space 3y = 18\space or\space y = 6  \\
# 12 + 2z = 4\space or \space 2z = -8\space or\space z = -4  \\
# v = 6 + 4\space or \space v = 10  \\
# $

# %%
# Проверка
import numpy as np

first = np.array([
    [6, 6, 9],
    [-3, 18, 12]
])

second = np.array([
    [2, 4, -10],
    [4, -12, -8]
])

first + second
# Out:
# array([[ 8, 10, -1],
#        [ 1,  6,  4]])

# %% [markdown]
# 1.3 На множестве $\mathbf{M}$ всех упорядоченных пар $(u; v)$ положительных чисел операции сложения и умножения введены
# следующим образом:
#
# $$
# (u_1; v_1) + (u_2; v_2) = (u_1 \cdot u_2; v_1 \cdot v_2);
# λ(u; v) = (u^{\lambda}; v^{\lambda}),
# $$
#
# где $\lambda$ – вещественное число. Докажите, что при этом множество $\mathbf{M}$ становится линейным пространством. Выясните: а) какая пара играет роль нулевого элемента; б) какая пара является противоположной паре $(u; v)$; в) укажите размерность этого пространства и какой-нибудь его базис.
#
# Ответ:
# Для линейного пространства должны быть выполнены 2 аксиомы:
# 1. Для любых его 2х элементов должна быть определена операция сложения, результат которого должен принадлежать тому же множеству.
# 2. Для любых его 2х элементов должна быть определена операция умножения, результат которой должен принадлежать тому же множеству.
#
# Так как множество у нас является парами положительных чисел, то можно сделать следующий вывод:
# 1. Результат сложения множества является парой положительных чисел, как как результатом умножения положительного числа на число тоже будет число. $(u_1 \cdot u_2; v_1 \cdot v_2)$
# 2. Так как $\lambda$ — вещественное число, то результат умножения множества тоже является парой положительных чисел. Так как возведение положительного числа в степень будет числом.
#
# Итого получаем, что результат сложения и умножения множества будет принадлежит этому же множеству и как следствие является линейным пространством.
#
# а) Зная, что имеем дело с векторным пространством можно найти нулевой элемент используя свойства линейного пространства:
#     $
#     \\
#     $
#     1. Произведение произвольного элемента линейного пространства на число 0 равно нулевому вектору: 0 • х = 0.
#     $
#     \\
#     $
#     2. Произведение нулевого вектора на любое число есть нулевой вектор: λ0 = 0
#
#  Получается пара (0,0) является нулевым вектором
#
# б) Вектор, противоположный данному вектору $(u; v)$, равен произведению $(u; v)$ на число -1: $(u; v)*-1 = (-u; -v)$
#
# в) размерность пространства — 2. определим какой-нибудь базис протранства
# $$
# u\cdot(1, 0) + v\cdot(0, 1)
# $$
#
# Базис равен
# $$
# (1,0), (0,1)
# $$
# в координатах {u,v}

# %% [markdown]
# 1.4 Докажите, что множество всех квадратных матриц второго порядка с известными операциями сложения и умножения на число образуют четырехмерное линейное пространство. Укажите какой-нибудь базис этого пространства.
#
# Так как мы знаем, что при использовании известных операций сложения и умножения на число мы получим то же самое множество квадратных матриц, то нужно доказать, что квадратные матрицы второго порядка имеют четырёхмерное линейное пространство.
# Для этого нужно найти максимальное число линейно независимых веторов данного пространства.
# $$
# e_1 = \begin{pmatrix} 1 & 0 \\ 0 & 0 \end{pmatrix}
# e_2 = \begin{pmatrix} 0 & 1 \\ 0 & 0 \end{pmatrix}
# e_3 = \begin{pmatrix} 0 & 0 \\ 1 & 0 \end{pmatrix}
# e_4 = \begin{pmatrix} 0 & 0 \\ 0 & 1 \end{pmatrix}
# $$
#
# Ранг этой матрицы равен 4. Следовательно, векторная система $e_1, e_2, e_3, e_4$ является линейно независимой а следовательно и пространство является четырёхмерным.
# Какой-нибудь базис пространства = (0,1,2,3)

# %% [markdown]
# 1.5 Укажите те значения параметров $p$ и $q$, при которых
# ранг матрицы $A = \begin{pmatrix} 1 & 2 & 3 \\ 3 & 6 & p \\ 5 & 10 & q \end{pmatrix}$ равен единице.
#
# Ответ:
# p = 9, q = 15

# %% [markdown]
# 1.6 Относительно канонического базиса в $\mathbb{R}^2$ даны три вектора $f_1 = (2, −5)$, $f_2 = (−1, 3)$, $x = (1, −4)$. Докажите, что векторы $f_1$ и $f_2$ можно принять за новый базис, и найдите координаты вектора $x$ в этом базисе
#
# Ответ:
#
# Предположим, что мы имеем новый базис векторов $f_1 = (2, −5)$, $f_2 = (−1, 3)$
# Тогда попробуем выразить новые значения исходных векторов через данный базис:
# $\begin{pmatrix} 2 \\ -5 \end{pmatrix} = x \begin{pmatrix} 2 \\ -5 \end{pmatrix} + y \begin{pmatrix} -1 \\ 3 \end{pmatrix}$ тоесто нужно найти такие координаты x,y при которых мы сможем значения исходной матрицы преобразовать в новый базис и обратно.
#
# Очевидно, что такие значения есть. При x = 1 и y = 0, мы получим исходную матрицу. Получается, что мы можем использовать базис $f_1 = (2, −5)$, $f_2 = (−1, 3)$ в координатах (1, 0) как минимум для первой матрицы. Давайте проверим данный базис для остальных матриц.
#
# $\begin{pmatrix} 1 \\ -3 \end{pmatrix} = x \begin{pmatrix} 2 \\ -5 \end{pmatrix} + y \begin{pmatrix} -1 \\ 3 \end{pmatrix}$ данный случай похож на первый вариант. Очевидно, что при координатах x = 0, y = 1 мы всё так же можем получить исходную матрицу в новом базисе.
#
# Осталось проверить последний вариант:
# $\begin{pmatrix} 1 \\ -4 \end{pmatrix} = x \begin{pmatrix} 2 \\ -5 \end{pmatrix} + y \begin{pmatrix} -1 \\ 3 \end{pmatrix}$
# И здесь тоже можно найти такие координаты, через которые монжо будет найти исходный вектор. x = -1, y = -3. Проверим:
# $-1 \begin{pmatrix} 2 \\ -5 \end{pmatrix} -3 \begin{pmatrix} -1 \\ 3 \end{pmatrix} = \begin{pmatrix} -2 \\ 5 \end{pmatrix} + \begin{pmatrix} 3 \\ -9 \end{pmatrix} = \begin{pmatrix} 1 \\ -4 \end{pmatrix}$
#
# Итого: базис векторов 𝑓1=(2,−5) , 𝑓2=(−1,3) можно использовать для данного векторного пространства

# %% [markdown]
# 1.7 Предположим, что существует линейный оператор, выраженный в базисе $(e_1, e_2)$ в виде матрицы $A = \begin{pmatrix} 1 & 0 \\ 0 & 2 \end{pmatrix}$. Найдите матрицу данного оператора в базисе из векторов $(\tilde{e}_1, \tilde{e}_2)$, если:
#
# $$
# \begin{cases}
# \tilde{e}_1 = -2e_1 + 5e_2 \\
# \tilde{e}_2 = -e_1 + 2e_2
# \end{cases}.
# $$
#
# Ответ:
#
# Зная формулу перехода от одного базиса к другому можно найти искомую матрицу:
# $$
# T = B^{-1} \cdot A \cdot B
# $$
#
# Где:
#
# T = искомая матрица $\\$
# B — матрица координат векторов нового базиса $\tilde{e}_1, \tilde{e}_2$:
#
# $$
# B = \begin{pmatrix} -2 & 5 \\ -1 & 2 \end{pmatrix}
# $$
#
# Находим обратную матрицу матрице B
#
# $$
# B^{-1} = \begin{pmatrix} -2 & 5 \\ -1 & 2 \end{pmatrix}^{-1} = 1/det B\begin{pmatrix} 2 & -5 \\ 1 & -2 \end{pmatrix} = 1/(-2\cdot2 - (-1)\cdot5)\cdot \begin{pmatrix} 2 & -5 \\ 1 & -2 \end{pmatrix} = \begin{pmatrix} 2 & -5 \\ 1 & -2 \end{pmatrix}
# $$
#
#
# Перемножаем все 3 матрицы:
# $$
# T = \begin{pmatrix} 2 & -5 \\ 1 & -2 \end{pmatrix}  \cdot \begin{pmatrix} 1 & 0 \\ 0 & 2 \end{pmatrix} \cdot \begin{pmatrix} -2 & 5 \\ -1 & 2 \end{pmatrix} = \begin{pmatrix} 6 & -10 \\ 2 & -3 \end{pmatrix}
# $$

# %% [markdown]
# ## 2. Начала математического анализа

# %% [markdown]
# 1. Найти матрицу Гессе следующей функции:
# $$
#     f(x,y) = x^3 - 2xy + y^2 - 3x - 2y.
# $$
#
#     Доп.задание (явно в курсе не обсуждалось): найдите точки локального экстремума функции $f$.
#
# Ответ:
#
# Так как матрица Гессе образована вторыми частными производными, то для начала нужно найти первые частные производные а замети и вторые:
# $$
# \frac{\partial f}{\partial x} = 3x^2 - 2y - 3\\
# \frac{\partial f}{\partial y} = -2x + 2y - 2
# $$
# Теперь нужно найти вторые частные производные по x для обоих вариантов и для y и можно сразу записать их в матрицу
# $$
# \begin{pmatrix} 6x & -2 \\ -2 & 2 \end{pmatrix}
# $$
#
# Для того, чтобы найти экстремумы нужно частные производные прировнять к нулю и решить систему уравнений:
# $$
# 3x^2 - 2y - 3 = 0 \\
# -2x + 2y - 2 = 0 \\
# $$
#
# из второго уравнения выражаем x:
#
# $x = y - 1$
#
# подставляем x в первое уравнение:
# $$
# 3(y-1)^2 - 2y - 3 = 0 \\
# или \\
# y(3y -8) = 0 \\
# откуда \\
# y_1 = 0; y_2 = 8/3 \\
# $$
#
# из второго уравнения выражаем y:
#
# $y = x + 1$
#
# подставляем y в первое уравнение:
# $$
# 3x^2 - 2(x+1) - 3 = 0 \\
# или \\
# 3x^2 - 2x -5 = 0 \\
# откуда \\
# x_1 = -1; x_2 = 5/3 \\
# $$
#
# Количество точек равно 2 M1(-1;0), M2(5/3;8/3)

# %% [markdown]
# 2. Проверьте, что функция $f = \ln(\sqrt{x} + \sqrt{y})$ удовлетворяет уравнению:
#
# $$
# x \frac{\partial f}{\partial x} + y \frac{\partial f}{\partial y} = \frac{1}{2}.
# $$
#
# Ответ:
#
# Найдём частные производные по x и y:
#
# $f = \ln(\sqrt{x}) +  \ln(\sqrt{y})$
#
# $\frac{\partial f}{\partial x} = \frac{1}{2x}$
#
# $\frac{\partial f}{\partial y} = \frac{1}{2y}$
#
# Подставляем найденные значения производных в уравнение:
#
# $x\frac{1}{2x} + y\frac{1}{2y} = \frac{1}{2}$
#
# Получается, что функция не удовлетворяет уравнению

# %% [markdown]
# 3. Используя правило для вычисления производной сложной функции, найдите полный дифференциал $\frac{df}{dt}$, если $$f = e^{xy}\ln(x+y), \quad x = 2t^2, \quad y = 1 - 2t^2 .$$
#
# Ответ:
#
# $(e^{xy}ln(x+y))' = (e^{xy})'ln(x+y)+e^{xy}(ln(x+y))'$
#
# В левой и правой части произведения имеем выражение 𝑙𝑛(𝑥+𝑦)
#
# Зная, что:
# $x + y = 2t^2 + 1 - 2t^2 = 1$
#
# Получаем что ln(x+y) = ln(1) = 0
#
#
# $\frac{df}{dt} = (e^{xy})'0+e^{xy}(0)' = 0$

# %% [markdown]
# 4. Предположим, задана функция $f: \mathbb{R}^3 \rightarrow \mathbb{R}^2$
#
# $$
#     f(x,y,z) = (x+y+z, xyz).
# $$
#
#    Найдите матрицу Якоби функции $f$, и её численное значение в точке $v = (1, 2, 3)$.
#
# Ответ:
# Зная входящую и исходящую размерность пространства делаем вывод, что матрица Якоби будет иметь размерность 2x3.
# Для того, чтобы найти данную матрицу нужно найти все частные производные функций по всем прараметрам(x,y,z). Тоесть:
#
# $J = \begin{pmatrix} \frac{df_1}{dx} & \frac{df_1}{dy} & \frac{df_1}{dz} \\
# \frac{df_2}{dx} & \frac{df_2}{dy} & \frac{df_2}{dz} \end{pmatrix} = \begin{pmatrix} 1 & 1 & 1 \\ yz & xz & xy \end{pmatrix}$
#
# Найдем численное значение матрицы в точке $v = (1, 2, 3)$:
#
# $\begin{pmatrix} 1 & 1 & 1 \\ 6 & 3 & 2 \end{pmatrix}$
